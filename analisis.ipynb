# %%
import pandas as pd
import os

# Ruta al archivo
dir = 'C:/Users/Usuario/Documents/Tecnicatura ISPC Ciencias de Datos/2025 - Analisis de Datos/Proyecto'
name = 'Universidades.xlsx'
data = os.path.join(dir, name)

# Leer y mostrar
df = pd.read_excel(data)

# Mostrar primeros 10 registros
print("Primeros 10 registros:")
print(df.head(11))

# Describir el dataset
print("\nDescripción estadística:")
print(df.describe(include='all'))
# Out:
# Primeros 10 registros:
#                    nombreUniversidad   sector     provincia  \
# 0   Universidad Cátolica de la Plata  Privada  Buenos Aires
# 1   Universidad Cátolica de la Plata  Privada  Buenos Aires
# 2   Universidad Cátolica de la Plata  Privada  Buenos Aires
# 3   Universidad Cátolica de la Plata  Privada  Buenos Aires
# 4   Universidad Cátolica de la Plata  Privada  Buenos Aires
# 5   Universidad Cátolica de la Plata  Privada  Buenos Aires
# 6   Universidad Cátolica de la Plata  Privada  Buenos Aires
# 7   Universidad Cátolica de la Plata  Privada  Buenos Aires
# 8   Universidad Cátolica de la Plata  Privada  Buenos Aires
# 9   Universidad Cátolica de la Plata  Privada  Buenos Aires
# 10  Universidad Cátolica de la Plata  Privada  Buenos Aires
#
#                                         nombreCarrera areaConocimiento  \
# 0        Lic. en Ciencias de la Educación a Distancia      Humanidades
# 1                                   Lic. en Filosofía      Humanidades
# 2                   Ciclo de Lic. en Educación Física      Humanidades
# 3           Ciclo de Lic. en Ciencias de la Educación      Humanidades
# 4              Ciclo de Lic. en Filosofía a Distancia      Humanidades
# 5                  Ciclo de Profesorado Universitario      Humanidades
# 6                          Ciclo de Lic. en Geografía      Humanidades
# 7                             Ciclo de Lic. en Letras      Humanidades
# 8                           Ciclo de Lic. en Historia      Humanidades
# 9   Tecnicatura en Entrenamiento Deportivo y Alto ...      Humanidades
# 10                Tecnicatura en Periodismo Deportivo      Humanidades
#
#                    nivel  modalidad    duracionAnios  \
# 0                  Grado  Distancia                4
# 1                  Grado  Distancia                4
# 2   Grado complementario  Distancia  3 cuatrimestres
# 3   Grado complementario  Distancia                2
# 4   Grado complementario  Distancia                2
# 5   Grado complementario  Distancia  3 cuatrimestres
# 6   Grado complementario  Distancia                2
# 7   Grado complementario  Distancia                2
# 8   Grado complementario  Distancia                2
# 9               Pregrado  Distancia                2
# 10              Pregrado  Distancia                2
#
#    cantidadCarrerasVirtuales  cantidadAreas  porcentajeOfertaVirtual  \
# 0                         19            4.0                      NaN
# 1                         19            4.0                      NaN
# 2                         19            4.0                      NaN
# 3                         19            4.0                      NaN
# 4                         19            4.0                      NaN
# 5                         19            4.0                      NaN
# 6                         19            4.0                      NaN
# 7                         19            4.0                      NaN
# 8                         19            4.0                      NaN
# 9                         19            4.0                      NaN
# 10                        19            4.0                      NaN
#
#    observaciones
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# 5            NaN
# 6            NaN
# 7            NaN
# 8            NaN
# 9            NaN
# 10           NaN
#
# Descripción estadística:
#             nombreUniversidad   sector     provincia nombreCarrera  \
# count                     924      924           924           924
# unique                     18        4            15           806
# top     Universidad Siglo XXI  privada  Buenos Aires      Abogacía
# freq                      273      392           372             9
# mean                      NaN      NaN           NaN           NaN
# std                       NaN      NaN           NaN           NaN
# min                       NaN      NaN           NaN           NaN
# 25%                       NaN      NaN           NaN           NaN
# 50%                       NaN      NaN           NaN           NaN
# 75%                       NaN      NaN           NaN           NaN
# max                       NaN      NaN           NaN           NaN
#
#              areaConocimiento                       nivel   modalidad  \
# count                     924                         920         923
# unique                     77                          19          42
# top     MANAGEMENT Y FINANZAS  pregrado, grado y posgrado  Presencial
# freq                       92                         392         241
# mean                      NaN                         NaN         NaN
# std                       NaN                         NaN         NaN
# min                       NaN                         NaN         NaN
# 25%                       NaN                         NaN         NaN
# 50%                       NaN                         NaN         NaN
# 75%                       NaN                         NaN         NaN
# max                       NaN                         NaN         NaN
#
#         duracionAnios  cantidadCarrerasVirtuales  cantidadAreas  \
# count           920.0                      913.0     912.000000
# unique           47.0                       15.0            NaN
# top               4.0                      255.0            NaN
# freq            199.0                      273.0            NaN
# mean              NaN                        NaN       7.245614
# std               NaN                        NaN       2.693853
# min               NaN                        NaN       1.000000
# 25%               NaN                        NaN       5.000000
# 50%               NaN                        NaN       8.000000
# 75%               NaN                        NaN      10.000000
# max               NaN                        NaN      11.000000
#
#         porcentajeOfertaVirtual  \
# count                640.000000
# unique                      NaN
# top                         NaN
# freq                        NaN
# mean                   3.052025
# std                    5.728531
# min                    0.000000
# 25%                    0.224100
# 50%                    0.734000
# 75%                    0.734000
# max                   15.740000
#
#                                             observaciones
# count                                                  22
# unique                                                  7
# top     Podés cursar en modalidad online hasta el 50% ...
# freq                                                   11
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
